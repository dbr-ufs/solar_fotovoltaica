# %% [markdown]
# # Posicionamento do Sol
#
# Esse material é baseado no código ``solarposition.py``
#
# Link do Principal Algoritmo: https://midcdmz.nrel.gov/spa/

# %% [markdown]
# ## Ajuste da nossa máquina Jupyter

# %%
import datetime

# scientific python add-ons
import numpy as np
import pandas as pd

# plotting stuff
# first line makes the plots appear in the notebook
# %matplotlib inline 
import matplotlib.pyplot as plt

# finally, we import the pvlib library

# %%
try:
  import pvlib
except ImportError:
  # !pip install pvlib
  import pvlib
  
from pvlib.location import Location

# %% [markdown]
# Código Fonte: https://pvlib-python.readthedocs.io/en/stable/_modules/pvlib/solarposition.html
#
# Principal Comando: https://pvlib-python.readthedocs.io/en/stable/generated/pvlib.solarposition.get_solarposition.html

# %% [markdown]
# ## Algoritmo de Localização Aparente do Sol

# %% [markdown]
# ### Localização
#
# Exemplos de cidades para os cálculos.

# %%
aju = Location(-10.9095, -37.0748, 'America/Bahia', 0, 'Aracaju')
print(aju)
tus = Location(32.2, -111, 'US/Arizona', 700, 'Tucson')
print(tus)
golden = Location(39.742476, -105.1786, 'America/Denver', 1830, 'Golden')
print(golden)
golden_mst = Location(39.742476, -105.1786, 'MST', 1830, 'Golden MST')
print(golden_mst)
berlin = Location(52.5167, 13.3833, 'Europe/Berlin', 34, 'Berlin')
print(berlin)
# Out:
# Location:
#   name: Aracaju
#   latitude: -10.9095
#   longitude: -37.0748
#   altitude: 0
#   tz: America/Bahia
# Location:
#   name: Tucson
#   latitude: 32.2
#   longitude: -111
#   altitude: 700
#   tz: US/Arizona
# Location:
#   name: Golden
#   latitude: 39.742476
#   longitude: -105.1786
#   altitude: 1830
#   tz: America/Denver
# Location:
#   name: Golden MST
#   latitude: 39.742476
#   longitude: -105.1786
#   altitude: 1830
#   tz: MST
# Location:
#   name: Berlin
#   latitude: 52.5167
#   longitude: 13.3833
#   altitude: 34
#   tz: Europe/Berlin

# %% [markdown]
# Escolhendo Aracaju como a localização.

# %%
loc = aju

# %% [markdown]
# ### Quando
#
# Definindo quando mostrar. No caso se escolheu para mostrar ontem e hoje.

# %%
times = pd.date_range(start=datetime.date.today()+datetime.timedelta(-1), end=datetime.date.today(), freq='1Min')
times_loc = times.tz_localize(loc.pytz)

# %% [markdown]
# ### Ângulos
#
# Verifique alguns ângulos usados na astronomia.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# onde a altura é o ângulo formado entre o horizonte e a posição aparente do sol, o ângulo zenital é o complemento (90 - altura) e o azimute é o ângulo entre o Norte e a projeção do Sol no horizonte, girando no sentido horário.

# %%
# !pip install ephem
# Out:
# Collecting ephem
#   Downloading ephem-3.7.7.1-cp38-cp38-win_amd64.whl (821 kB)
# Installing collected packages: ephem
# Successfully installed ephem-3.7.7.1

# %%
pyephemout = pvlib.solarposition.pyephem(times.tz_localize(loc.tz), loc.latitude, loc.longitude)
spaout = pvlib.solarposition.spa_python(times.tz_localize(loc.tz), loc.latitude, loc.longitude)

pyephemout['elevation'].plot(label='pyephem')
pyephemout['apparent_elevation'].plot(label='pyephem apparent')
spaout['elevation'].plot(label='spa')
plt.legend(ncol=2)
plt.title('Altura - '+loc.name)

print('pyephem')
print(pyephemout.head())
print('spa')
print(spaout.head())
# Out:
# pyephem
#                            apparent_elevation  apparent_azimuth  elevation  \
# 2020-11-11 00:00:00-03:00          -59.232405        157.352081 -59.232405
# 2020-11-11 00:01:00-03:00          -59.136871        156.925755 -59.136871
# 2020-11-11 00:02:00-03:00          -59.039663        156.502051 -59.039663
# 2020-11-11 00:03:00-03:00          -58.940796        156.081024 -58.940796
# 2020-11-11 00:04:00-03:00          -58.840290        155.662661 -58.840290
#
#                               azimuth  apparent_zenith      zenith
# 2020-11-11 00:00:00-03:00  157.352081       149.232405  149.232405
# 2020-11-11 00:01:00-03:00  156.925755       149.136871  149.136871
# 2020-11-11 00:02:00-03:00  156.502051       149.039663  149.039663
# 2020-11-11 00:03:00-03:00  156.081024       148.940796  148.940796
# 2020-11-11 00:04:00-03:00  155.662661       148.840290  148.840290
# spa
#                            apparent_zenith      zenith  apparent_elevation  \
# 2020-11-11 00:00:00-03:00       149.232401  149.232401          -59.232401
# 2020-11-11 00:01:00-03:00       149.136867  149.136867          -59.136867
# 2020-11-11 00:02:00-03:00       149.039658  149.039658          -59.039658
# 2020-11-11 00:03:00-03:00       148.940791  148.940791          -58.940791
# 2020-11-11 00:04:00-03:00       148.840281  148.840281          -58.840281
#
#                            elevation     azimuth  equation_of_time
# 2020-11-11 00:00:00-03:00 -59.232401  157.351839         15.988584
# 2020-11-11 00:01:00-03:00 -59.136867  156.925504         15.988503
# 2020-11-11 00:02:00-03:00 -59.039658  156.501809         15.988423
# 2020-11-11 00:03:00-03:00 -58.940791  156.080774         15.988342
# 2020-11-11 00:04:00-03:00 -58.840281  155.662419         15.988261

# %%
plt.figure()
pyephemout['elevation'].plot(label='pyephem')
spaout['elevation'].plot(label='spa')
(pyephemout['elevation'] - spaout['elevation']).plot(label='diff')
plt.legend(ncol=3)
plt.title('Altura - '+loc.name)

plt.figure()
pyephemout['apparent_elevation'].plot(label='pyephem apparent')
spaout['elevation'].plot(label='spa')
(pyephemout['apparent_elevation'] - spaout['elevation']).plot(label='diff')
plt.legend(ncol=3)
plt.title('Altura Aparente - '+loc.name)

plt.figure()
pyephemout['apparent_zenith'].plot(label='pyephem apparent')
spaout['zenith'].plot(label='spa')
(pyephemout['apparent_zenith'] - spaout['zenith']).plot(label='diff')
plt.legend(ncol=3)
plt.title('Zênite - '+loc.name)

plt.figure()
pyephemout['apparent_azimuth'].plot(label='pyephem apparent')
spaout['azimuth'].plot(label='spa')
(pyephemout['apparent_azimuth'] - spaout['azimuth']).plot(label='diff')
plt.legend(ncol=3)
plt.title('Azimute - '+loc.name)
# Out:
# Text(0.5, 1.0, 'Azimute - Aracaju')

# %% [markdown]
# ### Comando `get_solarposition`
#
# Mesmo comando, só mudar o method = 'nrel_numpy', 'nrel_numba', 'pyephem', 'ephemeris' ou 'nrel_c'

# %%
solpos = pvlib.solarposition.get_solarposition(times, loc.latitude, loc.longitude,method='nrel_numpy') # 'nrel_numpy', 'nrel_numba', 'pyephem', 'ephemeris', 'nrel_c' 
print(solpos.head())
solpos.plot()
plt.title(loc.name)
# Out:
#                      apparent_zenith      zenith  apparent_elevation  \
# 2020-11-11 00:00:00       136.716949  136.716949          -46.716949
# 2020-11-11 00:01:00       136.902875  136.902875          -46.902875
# 2020-11-11 00:02:00       137.088188  137.088188          -47.088188
# 2020-11-11 00:03:00       137.272878  137.272878          -47.272878
# 2020-11-11 00:04:00       137.456938  137.456938          -47.456938
#
#                      elevation     azimuth  equation_of_time
# 2020-11-11 00:00:00 -46.716949  229.393991         16.002972
# 2020-11-11 00:01:00 -46.902875  229.175908         16.002892
# 2020-11-11 00:02:00 -47.088188  228.955953         16.002813
# 2020-11-11 00:03:00 -47.272878  228.734108         16.002734
# 2020-11-11 00:04:00 -47.456938  228.510354         16.002655
# Text(0.5, 1.0, 'Aracaju')

# %% [markdown]
# ### Tarefa 1
#
#
# Comparar os algoritmos quanto a suas diferenças nos resultados. Observe que cada algoritmo apresenta o resultado de forma levemente diferente:
#
# https://pvlib-python.readthedocs.io/en/stable/generated/pvlib.solarposition.spa_python.html
#
# https://pvlib-python.readthedocs.io/en/stable/generated/pvlib.solarposition.pyephem.html
#
# https://pvlib-python.readthedocs.io/en/stable/generated/pvlib.solarposition.ephemeris.html
#
# https://pvlib-python.readthedocs.io/en/stable/generated/pvlib.solarposition.spa_c.html

# %% [markdown]
# ### Tarefa 2
#
# Sabemos que, apesar de estar no mesmo fuso horário, a posição do Sol não é a mesma em todos os locais. Mostre essa diferença, escolha dois locais dentro de um mesmo fuso horário, variando a longitude e, depois, variando a latitude e discuta os resultados. Mostre quais seriam as equações para fazer essas correções para a "hora real do Sol".
#
# https://www.pveducation.org/es/fotovoltaica/2-propiedades-de-la-luz-del-sol/posici%C3%B3n-del-sol
#
# Verifique na sequência o "solar_time"

# %%
pyephemout = pvlib.solarposition.pyephem(times.tz_localize(loc.tz), loc.latitude, loc.longitude)
ephemout = pvlib.solarposition.ephemeris(times.tz_localize(loc.tz), loc.latitude, loc.longitude)

pyephemout['elevation'].plot(label='pyephem')
pyephemout['apparent_elevation'].plot(label='pyephem apparent')
ephemout['elevation'].plot(label='ephem')
ephemout['apparent_elevation'].plot(label='ephem apparent')
plt.legend(ncol=2)
plt.title('Altura - '+loc.name)

print('pyephem')
print(pyephemout.head())
print('ephem')
print(ephemout.head())
# Out:
# pyephem
#                            apparent_elevation  apparent_azimuth  elevation  \
# 2020-11-11 00:00:00-03:00          -59.232405        157.352081 -59.232405
# 2020-11-11 00:01:00-03:00          -59.136871        156.925755 -59.136871
# 2020-11-11 00:02:00-03:00          -59.039663        156.502051 -59.039663
# 2020-11-11 00:03:00-03:00          -58.940796        156.081024 -58.940796
# 2020-11-11 00:04:00-03:00          -58.840290        155.662661 -58.840290
#
#                               azimuth  apparent_zenith      zenith
# 2020-11-11 00:00:00-03:00  157.352081       149.232405  149.232405
# 2020-11-11 00:01:00-03:00  156.925755       149.136871  149.136871
# 2020-11-11 00:02:00-03:00  156.502051       149.039663  149.039663
# 2020-11-11 00:03:00-03:00  156.081024       148.940796  148.940796
# 2020-11-11 00:04:00-03:00  155.662661       148.840290  148.840290
# ephem
#                            apparent_elevation  elevation     azimuth  \
# 2020-11-11 00:00:00-03:00          -59.230888 -59.230888  157.361334
# 2020-11-11 00:01:00-03:00          -59.135387 -59.135387  156.934976
# 2020-11-11 00:02:00-03:00          -59.038212 -59.038212  156.511257
# 2020-11-11 00:03:00-03:00          -58.939378 -58.939378  156.090197
# 2020-11-11 00:04:00-03:00          -58.838901 -58.838901  155.671815
#
#                            apparent_zenith      zenith  solar_time
# 2020-11-11 00:00:00-03:00       149.230888  149.230888    0.794463
# 2020-11-11 00:01:00-03:00       149.135387  149.135387    0.811128
# 2020-11-11 00:02:00-03:00       149.038212  149.038212    0.827793
# 2020-11-11 00:03:00-03:00       148.939378  148.939378    0.844459
# 2020-11-11 00:04:00-03:00       148.838901  148.838901    0.861124

# %% [markdown]
# ### Tarefa 3
#
# Considere que o nascer e o pôr do Sol ocorrem quando o Zenith = 90º. O que acontece com a duração dos dias nos solstícios de verão e inverno? E nos equinócios? Mostre nos calculos.

# %%
times = pd.date_range(start=datetime.date(2015,3,28), end=datetime.date(2015,3,29), freq='5min') # pd.DatetimeIndex

pyephemout = pvlib.solarposition.pyephem(times.tz_localize(loc.tz), loc.latitude, loc.longitude)
ephemout = pvlib.solarposition.ephemeris(times.tz_localize(loc.tz), loc.latitude, loc.longitude)

pyephemout['elevation'].plot(label='pyephem')
pyephemout['apparent_elevation'].plot(label='pyephem apparent')
ephemout['elevation'].plot(label='ephem')
plt.legend(ncol=2)
plt.title('Altura - '+loc.name)

plt.figure()
pyephemout['azimuth'].plot(label='pyephem')
ephemout['azimuth'].plot(label='ephem')
plt.legend(ncol=2)
plt.title('Azimute - '+loc.name)

print('pyephem')
print(pyephemout.head())
print('ephem')
print(ephemout.head())
# Out:
# pyephem
#                            apparent_elevation  apparent_azimuth  elevation  \
# 2015-03-28 00:00:00-03:00          -79.592099        140.489915 -79.592099
# 2015-03-28 00:05:00-03:00          -78.770666        135.474316 -78.770666
# 2015-03-28 00:10:00-03:00          -77.877837        131.156544 -77.877837
# 2015-03-28 00:15:00-03:00          -76.928229        127.435402 -76.928229
# 2015-03-28 00:20:00-03:00          -75.933351        124.216566 -75.933351
#
#                               azimuth  apparent_zenith      zenith
# 2015-03-28 00:00:00-03:00  140.489915       169.592099  169.592099
# 2015-03-28 00:05:00-03:00  135.474316       168.770666  168.770666
# 2015-03-28 00:10:00-03:00  131.156544       167.877837  167.877837
# 2015-03-28 00:15:00-03:00  127.435402       166.928229  166.928229
# 2015-03-28 00:20:00-03:00  124.216566       165.933351  165.933351
# ephem
#                            apparent_elevation  elevation     azimuth  \
# 2015-03-28 00:00:00-03:00          -79.593213 -79.593213  140.494557
# 2015-03-28 00:05:00-03:00          -78.771815 -78.771815  135.477926
# 2015-03-28 00:10:00-03:00          -77.878994 -77.878994  131.159323
# 2015-03-28 00:15:00-03:00          -76.929383 -76.929383  127.437514
# 2015-03-28 00:20:00-03:00          -75.934486 -75.934486  124.218154
#
#                            apparent_zenith      zenith  solar_time
# 2015-03-28 00:00:00-03:00       169.593213  169.593213    0.440440
# 2015-03-28 00:05:00-03:00       168.771815  168.771815    0.523791
# 2015-03-28 00:10:00-03:00       167.878994  167.878994    0.607141
# 2015-03-28 00:15:00-03:00       166.929383  166.929383    0.690492
# 2015-03-28 00:20:00-03:00       165.934486  165.934486    0.773843

# %%
times = pd.date_range(start=datetime.date(2015,3,30), end=datetime.date(2015,3,31), freq='5min')

pyephemout = pvlib.solarposition.pyephem(times.tz_localize(loc.tz), loc.latitude, loc.longitude)
ephemout = pvlib.solarposition.ephemeris(times.tz_localize(loc.tz), loc.latitude, loc.longitude)

pyephemout['elevation'].plot(label='pyephem')
pyephemout['apparent_elevation'].plot(label='pyephem apparent')
ephemout['elevation'].plot(label='ephem')
plt.legend(ncol=2)
plt.title('Altura - '+loc.name)

plt.figure()
pyephemout['azimuth'].plot(label='pyephem')
ephemout['azimuth'].plot(label='ephem')
plt.legend(ncol=2)
plt.title('Azimute - '+loc.name)

print('pyephem')
print(pyephemout.head())
print('ephem')
print(ephemout.head())
# Out:
# pyephem
#                            apparent_elevation  apparent_azimuth  elevation  \
# 2015-03-30 00:00:00-03:00          -80.088100        136.971179 -80.088100
# 2015-03-30 00:05:00-03:00          -79.212620        132.016751 -79.212620
# 2015-03-30 00:10:00-03:00          -78.271372        127.816690 -78.271372
# 2015-03-30 00:15:00-03:00          -77.278966        124.241633 -77.278966
# 2015-03-30 00:20:00-03:00          -76.246467        121.179577 -76.246467
#
#                               azimuth  apparent_zenith      zenith
# 2015-03-30 00:00:00-03:00  136.971179       170.088100  170.088100
# 2015-03-30 00:05:00-03:00  132.016751       169.212620  169.212620
# 2015-03-30 00:10:00-03:00  127.816690       168.271372  168.271372
# 2015-03-30 00:15:00-03:00  124.241633       167.278966  167.278966
# 2015-03-30 00:20:00-03:00  121.179577       166.246467  166.246467
# ephem
#                            apparent_elevation  elevation     azimuth  \
# 2015-03-30 00:00:00-03:00          -80.089493 -80.089493  136.975659
# 2015-03-30 00:05:00-03:00          -79.214032 -79.214032  132.020048
# 2015-03-30 00:10:00-03:00          -78.272788 -78.272788  127.819063
# 2015-03-30 00:15:00-03:00          -77.280363 -77.280363  124.243308
# 2015-03-30 00:20:00-03:00          -76.247841 -76.247841  121.180714
#
#                            apparent_zenith      zenith  solar_time
# 2015-03-30 00:00:00-03:00       170.089493  170.089493    0.450490
# 2015-03-30 00:05:00-03:00       169.214032  169.214032    0.533841
# 2015-03-30 00:10:00-03:00       168.272788  168.272788    0.617192
# 2015-03-30 00:15:00-03:00       167.280363  167.280363    0.700543
# 2015-03-30 00:20:00-03:00       166.247841  166.247841    0.783893

# %%
times = pd.date_range(start=datetime.date(2015,6,28), end=datetime.date(2015,6,29), freq='5min')

pyephemout = pvlib.solarposition.pyephem(times.tz_localize(loc.tz), loc.latitude, loc.longitude)
ephemout = pvlib.solarposition.ephemeris(times.tz_localize(loc.tz), loc.latitude, loc.longitude)

pyephemout['elevation'].plot(label='pyephem')
pyephemout['apparent_elevation'].plot(label='pyephem apparent')
ephemout['elevation'].plot(label='ephem')
plt.legend(ncol=2)
plt.title('Altura - '+loc.name)

plt.figure()
pyephemout['azimuth'].plot(label='pyephem')
ephemout['azimuth'].plot(label='ephem')
plt.legend(ncol=2)
plt.title('Azimute - '+loc.name)

print('pyephem')
print(pyephemout.head())
print('ephem')
print(ephemout.head())
# Out:
# pyephem
#                            apparent_elevation  apparent_azimuth  elevation  \
# 2015-06-28 00:00:00-03:00          -75.869174         27.886310 -75.869174
# 2015-06-28 00:05:00-03:00          -75.258337         31.786307 -75.258337
# 2015-06-28 00:10:00-03:00          -74.579566         35.345665 -74.579566
# 2015-06-28 00:15:00-03:00          -73.841441         38.577803 -73.841441
# 2015-06-28 00:20:00-03:00          -73.051756         41.503084 -73.051756
#
#                              azimuth  apparent_zenith      zenith
# 2015-06-28 00:00:00-03:00  27.886310       165.869174  165.869174
# 2015-06-28 00:05:00-03:00  31.786307       165.258337  165.258337
# 2015-06-28 00:10:00-03:00  35.345665       164.579566  164.579566
# 2015-06-28 00:15:00-03:00  38.577803       163.841441  163.841441
# 2015-06-28 00:20:00-03:00  41.503084       163.051756  163.051756
# ephem
#                            apparent_elevation  elevation    azimuth  \
# 2015-06-28 00:00:00-03:00          -75.867363 -75.867363  27.874989
# 2015-06-28 00:05:00-03:00          -75.256709 -75.256709  31.775115
# 2015-06-28 00:10:00-03:00          -74.578107 -74.578107  35.334716
# 2015-06-28 00:15:00-03:00          -73.840140 -73.840140  38.567175
# 2015-06-28 00:20:00-03:00          -73.050591 -73.050591  41.492826
#
#                            apparent_zenith      zenith  solar_time
# 2015-06-28 00:00:00-03:00       165.867363  165.867363    0.475988
# 2015-06-28 00:05:00-03:00       165.256709  165.256709    0.559310
# 2015-06-28 00:10:00-03:00       164.578107  164.578107    0.642631
# 2015-06-28 00:15:00-03:00       163.840140  163.840140    0.725952
# 2015-06-28 00:20:00-03:00       163.050591  163.050591    0.809274

# %%
pyephemout['elevation'].plot(label='pyephem')
pyephemout['apparent_elevation'].plot(label='pyephem apparent')
ephemout['elevation'].plot(label='ephem')
ephemout['apparent_elevation'].plot(label='ephem apparent')
plt.legend(ncol=2)
plt.title('Altura - '+loc.name)
plt.xlim(pd.Timestamp('2015-06-28 02:00:00+02:00'), pd.Timestamp('2015-06-28 06:00:00+02:00'))
plt.ylim(-10,10)
# Out:
# (-10.0, 10.0)

# %% [markdown]
# ### Tarefa 4
#
# Trace uma Analema. Trace um gráfico semelhante a este, mas para Aracaju:
#
# ![image.png](data:image/png;base64,...)
#
# Referência: https://pt.wikipedia.org/wiki/Analema

# %% [markdown]
# ### Tarefa 5
#
# Implemente e plote o caminho solar em sua cidade natal.
#
# Referência: https://pvlib-python.readthedocs.io/en/stable/auto_examples/plot_sunpath_diagrams.html
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Aprenda Mais
#
# Simuladores Online:
#
# http://www.heliodon.com.br/imagens.html
#
# https://www.pveducation.org/es/fotovoltaica/2-propiedades-de-la-luz-del-sol/calculadora-de-la-posici%C3%B3n-del-sol
